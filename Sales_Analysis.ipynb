# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('datasets/Global Superstore.txt',sep='\t')
df.head()
# Out:
#           Category         City        Country Customer ID     Customer Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  记录数               Order Date        Order ID  ... Sales  \
# 0       0.0     US    1  2011-01-07 00:00:00.000  CA-2011-130813  ...    19
# 1       0.0     US    1  2011-01-21 00:00:00.000  CA-2011-148614  ...    19
# 2       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...    21
# 3       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...   111
# 4       0.0     US    1  2011-09-29 00:00:00.000  CA-2011-146969  ...     6
#
# ...

# %%
df.tail()
# Out:
#               Category         City        Country Customer ID  \
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#         Customer Name  Discount Market  记录数               Order Date  \
# 51285  Alice McCarthy       0.2     US    1  2014-12-03 00:00:00.000
# 51286  Alice McCarthy       0.2     US    1  2014-12-03 00:00:00.000
# 51287  Hallie Redmond       0.2     US    1  2014-12-18 00:00:00.000
# 51288   Robert Marley       0.2     US    1  2014-12-25 00:00:00.000
# 51289    Fred Hopkins       0.2     US    1  2014-12-26 00:00:00.000
#
#              Order ID  ... Sales      Segment                Ship Date  \
# 51285  CA-2014-109701  ...    69    Corporate  2014-12-04 00:00:00.000
# ...

# %%
df.shape
# Out:
# (51290, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer ID     51290 non-null  object
#  4   Customer Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   记录数             51290 non-null  int64
#  8   Order Date      51290 non-null  object
#  9   Order ID        51290 non-null  object
#  10  Order Priority  51290 non-null  object
#  11  Product ID      51290 non-null  object
#  12  Product Name    51290 non-null  object
#  13  Profit          51290 non-null  float64
#  14  Quantity        51290 non-null  int64
#  15  Region          51290 non-null  object
#  16  Row ID          51290 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer ID', 'Customer Name',
#        'Discount', 'Market', '记录数', 'Order Date', 'Order ID', 'Order Priority',
#        'Product ID', 'Product Name', 'Profit', 'Quantity', 'Region', 'Row ID',
#        'Sales', 'Segment', 'Ship Date', 'Ship Mode', 'Shipping Cost', 'State',
#        'Sub-Category', 'Year', 'Market2', 'weeknum'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Category          0
# City              0
# Country           0
# Customer ID       0
# Customer Name     0
# Discount          0
# Market            0
# 记录数               0
# Order Date        0
# Order ID          0
# Order Priority    0
# Product ID        0
# Product Name      0
# Profit            0
# Quantity          0
# Region            0
# Row ID            0
# Sales             0
# Segment           0
# Ship Date         0
# Ship Mode         0
# Shipping Cost     0
# State             0
# Sub-Category      0
# Year              0
# Market2           0
# weeknum           0
# dtype: int64

# %%
df.describe()
# Out:
#            Discount      记录数        Profit      Quantity       Row ID  \
# count  51290.000000  51290.0  51290.000000  51290.000000  51290.00000
# mean       0.142908      1.0     28.610982      3.476545  25645.50000
# std        0.212280      0.0    174.340972      2.278766  14806.29199
# min        0.000000      1.0  -6599.978000      1.000000      1.00000
# 25%        0.000000      1.0      0.000000      2.000000  12823.25000
# 50%        0.000000      1.0      9.240000      3.000000  25645.50000
# 75%        0.200000      1.0     36.810000      5.000000  38467.75000
# max        0.850000      1.0   8399.976000     14.000000  51290.00000
#
#               Sales  Shipping Cost          Year       weeknum
# count  51290.000000   51290.000000  51290.000000  51290.000000
# mean     246.498440      26.375818   2012.777208     31.287112
# std      487.567175      57.296810      1.098931     14.429795
# min        0.000000       0.002000   2011.000000      1.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_copy=df.copy()

# %%
df_copy.head()
# Out:
#           Category         City        Country Customer ID     Customer Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  记录数               Order Date        Order ID  ... Sales  \
# 0       0.0     US    1  2011-01-07 00:00:00.000  CA-2011-130813  ...    19
# 1       0.0     US    1  2011-01-21 00:00:00.000  CA-2011-148614  ...    19
# 2       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...    21
# 3       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...   111
# 4       0.0     US    1  2011-09-29 00:00:00.000  CA-2011-146969  ...     6
#
# ...

# %%
df[['Order Date','Ship Date']]
# Out:
#                     Order Date                Ship Date
# 0      2011-01-07 00:00:00.000  2011-01-09 00:00:00.000
# 1      2011-01-21 00:00:00.000  2011-01-26 00:00:00.000
# 2      2011-08-05 00:00:00.000  2011-08-09 00:00:00.000
# 3      2011-08-05 00:00:00.000  2011-08-09 00:00:00.000
# 4      2011-09-29 00:00:00.000  2011-10-03 00:00:00.000
# ...                        ...                      ...
# 51285  2014-12-03 00:00:00.000  2014-12-04 00:00:00.000
# 51286  2014-12-03 00:00:00.000  2014-12-04 00:00:00.000
# 51287  2014-12-18 00:00:00.000  2014-12-21 00:00:00.000
# 51288  2014-12-25 00:00:00.000  2014-12-26 00:00:00.000
# 51289  2014-12-26 00:00:00.000  2014-12-30 00:00:00.000
#
# [51290 rows x 2 columns]

# %%
df.dtypes
# Out:
# Category           object
# City               object
# Country            object
# Customer ID        object
# Customer Name      object
# Discount          float64
# Market             object
# 记录数                 int64
# Order Date         object
# Order ID           object
# Order Priority     object
# Product ID         object
# Product Name       object
# Profit            float64
# Quantity            int64
# Region             object
# Row ID              int64
# Sales               int64
# Segment            object
# Ship Date          object
# Ship Mode          object
# Shipping Cost     float64
# State              object
# Sub-Category       object
# Year                int64
# Market2            object
# weeknum             int64
# dtype: object

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])
df['Ship Date']=pd.to_datetime(df['Ship Date'])

# %%
df.dtypes
# Out:
# Category                  object
# City                      object
# Country                   object
# Customer ID               object
# Customer Name             object
# Discount                 float64
# Market                    object
# 记录数                        int64
# Order Date        datetime64[ns]
# Order ID                  object
# Order Priority            object
# Product ID                object
# Product Name              object
# Profit                   float64
# Quantity                   int64
# Region                    object
# Row ID                     int64
# Sales                      int64
# Segment                   object
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Shipping Cost            float64
# State                     object
# Sub-Category              object
# Year                       int64
# Market2                   object
# weeknum                    int64
# dtype: object

# %%
df['Month']=df['Order Date'].dt.month_name()

# %%
df['Quarter'] = df['Order Date'].dt.quarter

# %%
df['Day']=df['Order Date'].dt.day_name()

# %%
df.dtypes
# Out:
# Category                  object
# City                      object
# Country                   object
# Customer ID               object
# Customer Name             object
# Discount                 float64
# Market                    object
# 记录数                        int64
# Order Date        datetime64[ns]
# Order ID                  object
# Order Priority            object
# Product ID                object
# Product Name              object
# Profit                   float64
# Quantity                   int64
# Region                    object
# Row ID                     int64
# Sales                      int64
# Segment                   object
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Shipping Cost            float64
# State                     object
# Sub-Category              object
# Year                       int64
# Market2                   object
# weeknum                    int64
# Month                     object
# ...

# %%
df.to_csv('datasets/cleaned_superstore.csv',index=False)

# %%
# What is the total sales of the company?
df['Sales'].sum()
# Out:
# 12642905

# %%
# What is the total profit earned by the company?
df['Profit'].sum()
# Out:
# 1467457.2912800002

# %%
# How many unique orders were placed?
df['Order ID'].nunique()
# Out:
# 25035

# %%
# How many unique customers purchased products?
df['Customer ID'].nunique()
# Out:
# 4873

# %%
# How many unique products were sold?
df['Product ID'].nunique()
# Out:
# 10292

# %%
# What is the total quantity of products sold?
df['Quantity'].sum()
# Out:
# 178312

# %%
# What is the average sales per order?
df.groupby('Order ID')['Sales'].sum().mean()
# Out:
# 505.0091871380068

# %%
# What is the average profit per order?
df.groupby('Order ID')['Profit'].sum().mean()
# Out:
# 58.616228930697034

# %%
# Which region has the highest total sales?
df.groupby('Region')['Sales'].sum().sort_values(ascending=False).head(1)
# Out:
# Region
# Central    2822399
# Name: Sales, dtype: int64

# %%
# Which state has the highest sales?
df.groupby('State')['Sales'].sum().sort_values(ascending=False).head(1)
# Out:
# State
# England    485166
# Name: Sales, dtype: int64

# %%
# Which city generated the highest revenue?
df.groupby('City')['Sales'].sum().sort_values(ascending=False).head(1)
# Out:
# City
# New York City    256397
# Name: Sales, dtype: int64

# %%
# Which customer segment contributes the highest sales?
df.groupby('Segment')['Sales'].sum().sort_values(ascending=False).head(1)
# Out:
# Segment
# Consumer    6508141
# Name: Sales, dtype: int64

# %%
# Which category generates the highest sales?
df.groupby('Category')['Sales'].sum().sort_values(ascending=False).head(1)
# Out:
# Category
# Technology    4744691
# Name: Sales, dtype: int64

# %%
# Which sub-category generates the highest profit?
df.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False).head(1)
# Out:
# Sub-Category
# Copiers    258567.54818
# Name: Profit, dtype: float64

# %%
# What are the Top 10 selling products?
df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Product Name
# Apple Smart Phone, Full Size                                86936
# Cisco Smart Phone, Full Size                                76441
# Motorola Smart Phone, Full Size                             73159
# Nokia Smart Phone, Full Size                                71904
# Canon imageCLASS 2200 Advanced Copier                       61600
# Hon Executive Leather Armchair, Adjustable                  58200
# Office Star Executive Leather Armchair, Adjustable          50667
# Harbour Creations Executive Leather Armchair, Adjustable    50120
# Samsung Smart Phone, Cordless                               48654
# Nokia Smart Phone, with Caller ID                           47880
# Name: Sales, dtype: int64

# %%
# Which products are making losses?
df[df['Profit']<0][['Product Name','Profit']]
# Out:
#                                             Product Name    Profit
# 29009                      Nokia Headset, with Caller ID  -24.2715
# 29012                      Canon Fax Machine, High-Speed  -19.0170
# 29018                           StarTech Calculator, Red   -0.0495
# 29021                      Samsung Audio Dock, Full Size   -6.7560
# 29024                           Canon Fax Machine, Laser -111.4995
# ...                                                  ...       ...
# 51156         Motorola HK250 Universal Bluetooth Headset  -12.4146
# 51163  Anker Astro Mini 3000mAh Ultra-Compact Portabl...   -7.9960
# 51164         Motorola HK250 Universal Bluetooth Headset  -20.6910
# 51180                        Shocksock Galaxy S4 Armband   -3.5040
# 51186         Motorola HK250 Universal Bluetooth Headset  -28.9674
#
# [12544 rows x 2 columns]

# %%
# Who are the Top 10 customers based on sales?
df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Customer Name
# Tom Ashbrook          40489
# Tamara Chand          37453
# Greg Tran             35552
# Christopher Conant    35187
# Sean Miller           35170
# Bart Watters          32315
# Natalie Fritzler      31778
# Fred Hopkins          30404
# Jane Waco             30288
# Hunter Lopez          30246
# Name: Sales, dtype: int64

# %%
# Which customer generated the highest profit?
df.groupby('Customer Name')['Profit'].sum().sort_values(ascending=False).head(1)
# Out:
# Customer Name
# Tamara Chand    8672.8989
# Name: Profit, dtype: float64

# %%
# Which customers placed the most orders?
df.groupby('Customer Name')['Order ID'].nunique().sort_values(ascending=False).head(1)
# Out:
# Customer Name
# Frank Olsen    47
# Name: Order ID, dtype: int64

# %%
# Which year had the highest sales?
df.groupby('Year')['Sales'].sum().sort_values(ascending=False).head(1)
# Out:
# Year
# 2014    4300041
# Name: Sales, dtype: int64

# %%
# Which month had the highest sales?
df.groupby('Month')['Sales'].sum().sort_values(ascending=False).head(1)
# Out:
# Month
# December    1580816
# Name: Sales, dtype: int64

# %%
# Which quarter generated the highest profit?
df.groupby('Quarter')['Profit'].sum().sort_values(ascending=False).head(1)
# Out:
# Quarter
# 4    503436.9696
# Name: Profit, dtype: float64

# %%
# Which day of the week receives the most orders?
df.groupby('Day')['Order ID'].nunique().sort_values(ascending=False).head(1)
# Out:
# Day
# Tuesday    4632
# Name: Order ID, dtype: int64

# %%
# Which region is the most profitable?
df.groupby('Region')['Profit'].sum().sort_values(ascending=False).head(1)
# Out:
# Region
# Central    311403.98164
# Name: Profit, dtype: float64

# %%
# Which category has the lowest profit?
df.groupby('Category')['Profit'].sum().sort_values().head(1)
# Out:
# Category
# Furniture    285204.7238
# Name: Profit, dtype: float64

# %%
# Which states are running at a loss?
loss_states = df.groupby('State')['Profit'].sum()
loss_states[loss_states < 0]
# Out:
# State
# 'Ajman                     -332.71200
# Abia                      -1475.55600
# Abuja Capital Territory     -67.61400
# Aceh                        -49.67430
# Adamawa                    -289.02900
#                               ...
# Zealand                    -245.04300
# Zeeland                    -100.17000
# Zhambyl                     -28.59000
# Zulia                      -994.14304
# Šiauliai                   -164.73900
# Name: Profit, Length: 290, dtype: float64

# %%
# What is the overall profit margin?
(df['Profit'].sum() / df['Sales'].sum()) * 100
# Out:
# 11.606962887722403

# %%
# Does a higher discount always lead to higher sales?
df.groupby('Discount')['Sales'].mean().plot(kind='bar')
plt.xlabel('Discount')
plt.ylabel('Average Sales')
plt.title('Average Sales by Discount')
plt.show()

# %%
# Which category receives the highest average discount?
df.groupby('Category')['Discount'].mean().sort_values(ascending=False).head(1)
# Out:
# Category
# Furniture    0.168087
# Name: Discount, dtype: float64

# %%
# Which products have the highest discounts?
df.groupby('Product Name')['Discount'].mean().sort_values(ascending=False).head(1)
# Out:
# Product Name
# Eureka Disposable Bags for Sanitaire Vibra Groomer I Upright Vac    0.8
# Name: Discount, dtype: float64

# %%
# How have total sales changed over the years?
df.groupby('Year')['Sales'].sum().plot(kind='line', marker='o',c='Green',markerfacecolor='Blue')
plt.xlabel('Years')
plt.ylabel('Sales')
plt.title('Total Sales Changed over Years')
plt.show()

# %%
# Which region generates the highest total sales?
df.groupby('Region')['Sales'].sum().sort_values(ascending=False).plot(
    kind='bar'
)

plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region')
plt.show()

# %%
# Which category generates the highest total profit?
df.groupby('Category')['Profit'].sum().sort_values(ascending=False).plot(kind='bar')
plt.xlabel('Category')
plt.ylabel('Total Profit')
plt.title('Total Profit By Category')
plt.show()

# %%
# Which are the Top 10 products by total sales?
df.groupby('Product Name')['Sales'].sum().sort_values(ascending=True).tail(10).plot(kind='barh')

plt.xlabel('Total Sales')
plt.ylabel('Product')
plt.title('Top 10 Products by Total Sales')
plt.show()

# %%
# Which sub-category generates the highest total profit?
df.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False).plot(kind='bar')
plt.xlabel('Sub-Category')
plt.ylabel('Profit')
plt.title('Highest Total Profit By Sub-Category')
plt.show()

# %%
# Which region has the highest total profit?
df.groupby('Region')['Profit'].sum().sort_values(ascending=False).plot(kind='bar')
plt.xlabel('Region')
plt.ylabel('Total Profit')
plt.title('Highest Total Profit By Region')
plt.show()

# %%
# Which customer segment generates the highest total sales?
df.groupby('Segment')['Sales'].sum().sort_values(ascending=False).plot(kind='bar')
plt.xlabel('Segment')
plt.ylabel('Total Sales')
plt.title('Total Sales by Customer Segment')
plt.show()

# %%
# Which state has the highest total sales?
df.groupby('State')['Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.xlabel('State')
plt.ylabel('Total Sales')
plt.title('Highest Total Sales by State')
plt.show()

# %%
# Which month has the highest total sales?
df.groupby('Month')['Sales'].sum().sort_values(ascending=False).plot(kind='line', marker='o')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.title('Highest Total Sales By Month')
plt.show()

# %%
# Which customer has generated the highest total sales?
df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.xlabel('Customer Name')
plt.ylabel('Total Sales')
plt.title('Total Sales By Top 10 Customer')
plt.show()

# %%
# Which states have the highest total profit?
df.groupby('State')['Profit'].sum().sort_values(ascending=False).head(10).plot(kind='barh')
plt.xlabel('State')
plt.ylabel('Total Profit')
plt.title('Total Profit by State')
plt.show()

# %%
# How does profit change over the years?
df.groupby('Year')['Profit'].sum().plot(kind='line',marker='o')
plt.xlabel('Years')
plt.ylabel('Total Profit')
plt.title('Profit Trend by Year')
plt.show()

# %%
# Does higher discount affect profit?
plt.scatter(df['Discount'], df['Profit'])
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.title('Discount vs Profit')
plt.show()

# %%
# Which category has the highest average discount?
df.groupby('Category')['Discount'].mean().plot(kind='bar')
plt.xlabel('Category')
plt.ylabel('Average Discount')
plt.title('Average Discount By Category')
plt.show()

# %%
# Which sub-category has the highest profit margin?
subcat_margin = (
    df.groupby('Sub-Category')[['Profit', 'Sales']]
      .sum()
)

subcat_margin['Profit_Margin'] = (
    subcat_margin['Profit'] / subcat_margin['Sales'] * 100
)

subcat_margin['Profit_Margin'].sort_values(ascending=False).head(10).plot(kind='bar')

plt.xlabel('Sub-Category')
plt.ylabel('Profit Margin (%)')
plt.title('Top 10 Sub-Categories by Profit Margin')
plt.show()

# %%
# Which region has the highest profit margin?
region_margin = (
    df.groupby('Region')[['Profit', 'Sales']]
      .sum()
)

region_margin['Profit_Margin'] = (
    region_margin['Profit'] / region_margin['Sales'] * 100
)

region_margin['Profit_Margin'].sort_values(ascending=False).head(10).plot(kind='bar')

plt.xlabel('Region')
plt.ylabel('Profit Margin (%)')
plt.title('tTop 10 Region by Profit Margin')
plt.show()

# %%
# Which shipping mode has the highest total sales?
df.groupby('Ship Mode')['Sales'].sum().sort_values(ascending=False).plot(kind='bar')
plt.xlabel('Ship Mode')
plt.ylabel('Total Sales')
plt.title('Ship Mode By Total Sales')
plt.show()

# %%
# Which order priority generates the highest total sales?
df.groupby('Order Priority')['Sales'].sum().sort_values(ascending=False).plot(kind='bar')
plt.xlabel('Order Priority')
plt.ylabel('Total Sales')
plt.title('Total Sales by Order Priority')
plt.show()

# %%
# Which category has the highest total quantity sold?
df.groupby('Category')['Quantity'].sum().sort_values(ascending=False).plot(kind='bar')
plt.xlabel('Category')
plt.ylabel('Quantity')
plt.title('Category by Quantity')
plt.show()
